# %% [markdown]
# THIS NOTEBOOK IS ABOUT LIBRARIES USED IN DATA SCIENCE

# %% [markdown]
# 1. pandas- ye excel type hai us se zada function hongy
# 2. numpy- data type ko samjhne k liye
# 3. matplotlib- for plotting, graphs or line bar, bar chart ye sab
# 4. seaborn- is based on matplotlib matlab matplotlib bhi hai seaborn mai but extra functions bhi hain but alag hai
# 5. plotly- dashboards, or graphs, 3d animated plots ye sab
# 6. scipy- stats k liye
# 7. scikit-learn - machine learning k liye
# 8. streamlit- to make ala kisam k dashboards or to make apps

# %%
#pip install pandas

# %%
#pip install pandas numpy matplotlib seaborn plotly

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px
# Out:
# Matplotlib is building the font cache; this may take a moment.
