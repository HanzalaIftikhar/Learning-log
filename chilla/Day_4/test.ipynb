# %% [markdown]
# Subject of this notebook: \
# Author: Hanzala Iftikhar\
# Date: 10-09-2025\
# Contact details: https://github.com/HanzalaIftikhar

# %% [markdown]
# **My first code in JN**

# %%
print("hello")
# Out:
# hello

# %%
age = int(input("What is Ali's age? "))
minimum_age_at_school = 5
max_age_at_school = 20
if age>= minimum_age_at_school and age<= max_age_at_school:
    print("Ali can attend school")

elif age>= max_age_at_school:
    print("Ali is too old to attend school")
else:
    print("Ali cannot attend school")
# Out:
# Ali cannot attend school

# %% [markdown]
# test program

# %%
print("hello")
# Out:
# hello

# %%
print(4+6*6/2)
# Out:
# 22.0

# %%
print("hello")
# Out:
# hello
