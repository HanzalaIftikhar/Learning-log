# %%
name = "Hanzala"

# %%
len(name)
# Out:
# 7

# %%
name[0]
# Out:
# 'H'

# %%
# kinda range bhi keh sakty
name[2:5]
# Out:
# 'nza'

# %%
# negative indexing hamesha right side se start hota hai
name[-5:-1]
# Out:
# 'nzal'
