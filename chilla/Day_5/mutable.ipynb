# %% [markdown]
# This jPN is about mutables in python

# %%
list = [10,20,30,40,50]

# %%
list[2]= 43

# %%
list
# Out:
# [10, 20, 43, 40, 50]

# %% [markdown]
# **tuple is immutable**

# %%
tuple=(10,20,30,40,50)

# %%
tuple[2]= 43
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tuple[2]= 43
#
# TypeError: 'tuple' object does not support item assignment
